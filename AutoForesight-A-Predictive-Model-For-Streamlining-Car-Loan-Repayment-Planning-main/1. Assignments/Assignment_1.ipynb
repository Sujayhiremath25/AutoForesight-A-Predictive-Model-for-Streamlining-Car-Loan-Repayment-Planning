# %%
import pandas as pd
import numpy as np

# %%
# Create a pandas dataframe with numpy random values
data = np.random.randn(4, 4)#4 rows and 4 columns
df = pd.DataFrame(data)

# %%
# Rename columns
df.columns = ['Random value 1', 'Random value 2', 'Random value 3', 'Random value 4']

# %%
df.head()
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        1.164889        0.611263        0.016332        0.504037
# 1        1.353117       -0.569032       -0.198372       -1.323396
# 2        0.241580        1.027847       -1.765539       -0.878812
# 3       -0.951761       -1.726242       -1.442396       -1.294689

# %%
# Descriptive statistics
print("Descriptive Statistics:")
print(df.describe())
# Out:
# Descriptive Statistics:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.451956       -0.164041       -0.847494       -0.748215
# std          1.054363        1.241797        0.887744        0.859197
# min         -0.951761       -1.726242       -1.765539       -1.323396
# 25%         -0.056755       -0.858334       -1.523182       -1.301866
# 50%          0.703235        0.021116       -0.820384       -1.086750
# 75%          1.211946        0.715409       -0.144696       -0.533100
# max          1.353117        1.027847        0.016332        0.504037

# %%
# Check for null values and data types
print("\nNull Values:")
print(df.isnull().sum())
# Out:
# Null Values:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64

# %%
print("\nData Types:")
print(df.dtypes)
# Out:
# Data Types:
# Random value 1    float64
# Random value 2    float64
# Random value 3    float64
# Random value 4    float64
# dtype: object

# %%
# Display 'Random value 2' & 'Random value 3' columns with location method and index location method
print("\nRandom value 2 column with location method:")
print(df.loc[:, 'Random value 2'])


print("\nRandom value 3 column with location method:")
print(df.loc[:, 'Random value 3'])

print("\nRandom value 2 column with index location method:")
print(df.iloc[:, 1])

print("\nRandom value 3 column with index location method:")
print(df.iloc[:, 2])
# Out:
# Random value 2 column with location method:
# 0    0.611263
# 1   -0.569032
# 2    1.027847
# 3   -1.726242
# Name: Random value 2, dtype: float64
#
# Random value 3 column with location method:
# 0    0.016332
# 1   -0.198372
# 2   -1.765539
# 3   -1.442396
# Name: Random value 3, dtype: float64
#
# Random value 2 column with index location method:
# 0    0.611263
# 1   -0.569032
# 2    1.027847
# 3   -1.726242
# Name: Random value 2, dtype: float64
#
# Random value 3 column with index location method:
# 0    0.016332
# 1   -0.198372
# 2   -1.765539
# 3   -1.442396
# Name: Random value 3, dtype: float64
